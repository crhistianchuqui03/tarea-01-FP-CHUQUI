# %% [markdown]
# 2.1 Realice un diagrama de flujo y pseudocódigo que representen el algoritmo para obtener el área de un triángulo.

# %%
#DEFINIR DATOS
base:float
altura:float
area:float
#DATOS DE ENTRADA
base=float(input("ingrese la base:"))
altura=float(input("ingrese la altura:"))
#PROCESO
area=base*altura/2
#DATOS DE SALIDA 
print(f"el area es: {area}")
# Out:
# ingrese la base:10
# ingrese la altura:15
# el area es: 75.0

# %% [markdown]
# 2.2 Una empresa importadora desea determinar cuántos dólares puede adquirir con equis cantidad de dinero en soles realice un diagrama de flujo y pseudocódigo que represente un algoritmo para tal fin.

# %%
#DEFINIR DATOS
nmrsoles:float 
nmrdolares:float=3.77
#DATOS DE ENTRADA 
nmrsoles=float(input("ingrese nmrsoles:"))
#PROCESO
nmrdolares=nmrsoles/nmrdolares
#DATOS DE SALIDA 
print(f"el nmrdolares es:{nmrdolares}")
# Out:
# ingrese nmrsoles:10
# el nmrdolares es:2.6525198938992043

# %% [markdown]
# 2.3 Una empresa que contrata personal requiere determinar la edad de las personas que solicitan trabajo, pero cuando se les realiza la entrevista sólo se les pregunta el año en que nacieron.  Realice el diagrama de flujo y pseudocódigo que represente el algoritmo para solucionar este problema.

# %%
#DEFINIR DATOS
añoactual:float
añonacido:float
edad:float
#DATOS DE ENTRADA
añoactual=float(input("ingrese el año actual:"))
añonacido=float(input("ingrese el año nacido:"))
#PROCESO
edad=añoactual-añonacido
#DATOS DE SALIDA
print(f"el año que tiene es:{edad}")
# Out:
# ingrese el año actual:2022
# ingrese el año nacido:2003
# el año que tiene es:19.0

# %% [markdown]
# 2.4 Un estacionamiento requiere determinar el cobro que debe aplicar a las personas que lo utilizan. Considere que el cobro es con base en las horas que lo disponen y que las fracciones de hora se toman como completas y realice un diagrama de flujo y pseudocódigo que represente el algoritmo que permita determinar el cobro.

# %%
#DATOS DE ENTRADA
pgporhora:float
hrest:float
cbrtotal:float
#DATOS DE ENTRADA
pgoporhora=float(input("ingrese el pago por hora:"))
hrest=float(input("ingrese la hora estacionada:"))
#PROCESO
cbrtotal=pgoporhora*hrest
#DATOS DE SALIDA
print(f"el cobro total es:{cbrtotal}")
# Out:
# ingrese el pago por hora:5
# ingrese la hora estacionada:9
# el cobro totales:45.0

# %% [markdown]
# 2.5 Constructoras Juliaca requiere determinar cuánto cobrar por trabajos de pintura. Considere que se cobra por m2 y realice un diagrama de flujo y pseudocódigo que represente el algoritmo que le permita ir generando presupuestos para cada cliente.

# %%
#DATOS DE ENTRADA
min2:float
cobro:float
cantidad:float
cbrtotal:float
#DATOS DE ENTRADA
min2=float(input("ingrese los minutos al cuadrado:"))
cobro=float(input("ingrese el moto de cobro por min^2:"))
cantidad=float(input("ingrese la cantidad de pintura:"))
#PROCESO
cbrtotal=min2*cobro*2*cantidad
#DATOS DE SALIDA 
print(f"el cobro total es:{cbrtotal}")
# Out:
# ingrese los minutos al cuadrado:2
# ingrese el moto de cobro por min^2:2
# ingrese la cantidad de pintura:2
# el cobro total es:16.0

# %% [markdown]
# 2.6 Se requiere determinar la hipotenusa de un triángulo rectángulo ¿cómo sería el diagrama de flujo y el pseudocódigo que represente el algoritmo para obtenerla? Recuerde que por Pitágoras c^ {2} =a^ {2} +b^ {2}

# %%
#referenciar libreria
import math
#Definir variables
ladoA:float
ladoB:float
hipotenusa:float
#Datos de entrada
ladoA=float(input("Ingrese el lado A del Triangulo:"))
ladoB=float(input("Ingrese el lado B del Triangulo:"))
#Proceso
hipotenusa=math.sqrt(math.pow(ladoA,2)+math.pow(ladoB,2))
#Datos de salida
print(f"La hipotenusa del triangulo rectangulo es: {hipotenusa}")
# Out:
# Ingrese el lado A del Triangulo:2
# Ingrese el lado B del Triangulo:2
# La hipotenusa del triangulo rectangulo es: 2.8284271247461903

# %% [markdown]
# 2.7 Una compañía de autobuses requiere determinar el costo que tendrá el boleto de un viaje, esto basado en los kilómetros por recorrer y el costo es por kilómetro. Realice un diagrama de flujo y pseudocódigo que representen el algoritmo para tal fin.

# %%
#DEFINIR DATOS
cstboleto:float 
nmrkilometros:float=10
#DATOS DE ENTRADA 
cstboleto=float(input("ingrese nmrkilometros:"))
#PROCESO
nmrkilometros=cstboleto*nmrkilometros
#DATOS DE SALIDA 
print(f"el nmrkilometro es:{nmrkilometros}")
# Out:
# ingrese nmrkilometros:6
# el nmrkilometro es:60.0

# %% [markdown]
# 2.8 Se requiere determinar el tiempo que tarda una persona en llegar de una ciudad a otra en bicicleta, considerando que lleva una velocidad constante. Realice un diagrama de flujo y pseudocódigo que represente el algoritmo para tal fin.

# %%
4#DEFINIR DATOS 
tiempo:float
distancia:float
velocidad:float
#DATOS DE ENTRADA
distancia=float(input("ingrese distancia"))
velocidad=float(input("ingrese velocidad"))
#PROCESO
tiempo=distancia/velocidad
#DATOS DE SALIDA
print(f"el tiempo es:{tiempo}")
# Out:
# ingrese distancia8
# ingrese velocidad2
# el tiempo es:4.0

# %% [markdown]
# 2.9 Se requiere determinar el costo que tendrá, el realizar una llamada telefónica con base en el tiempo que dura la llamada y el costo es por minuto. realice un diagrama de flujo y pseudocódigo que representen el algoritmo para tal fin.

# %%
#DATOS DE ENTRADA
cstllamda:float
tmpllamada:float
cstminuto:float
#DATOS DE ENTRADA 
tmpllamada=float(input("ingrese el tiempo dela llamada"))
cstminuto=float(input("ingrese el costo por minuto"))
#PROCESO
cstllamada=tmpllamada*cstminuto
#DATOS DE SALIDA 
print(f"el cstllamada es:{cstllamada}")
# Out:
# ingrese el tiempo dela llamada2
# ingrese el costo por minuto10
# el cstllamada es:20.0

# %% [markdown]
# 2.10 Seda Juliaca requiere determinar el pago que debe realizar una persona por el total de metros cúbicos de consumo de agua. Realice un diagrama de flujo y pseudocódigo que represente el algoritmo que permita determinar ese pago.

# %%
#DATOS DE ENTRADA 
pgtotal:float
mtcdca:float
cstagua:float=2.35
#DATOS DE ENTRADA 
mtcdca=float(input("ingrese la cantidad de metros cubicos de consumo de agua"))
#PROCESO
pgtotal=mtcdca*cstagua
#DATOS DE SALIDA 
print(f"el pgtotal es:{pgtotal}")
# Out:
# ingrese la cantidad de metros cubicos de consumo de agua4
# el pgtotal es:9.4
